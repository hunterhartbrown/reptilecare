# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('C:/Users/Hunter/Desktop/Excel/Website/reptilecare/data/Reptile Care Sheet.xlsx', engine='openpyxl')

# Convert the DataFrame to JSON
json_data = df.to_json(orient='records')

# Save the JSON data to a file
with open('C:/Users/Hunter/Desktop/Excel/Website/reptilecare/data/reptile_care_data.json', 'w') as json_file:
    json_file.write(json_data)
